# %%
import pandas as pd
import re

# %%
CLINICAL_DATA_PATH_1 = "../data/broad_tcga/clinical/gdac.broadinstitute.org_STAD.Clinical_Pick_Tier1.Level_4.2016012800.0.0.tar.gz"
CLINICAL_DATA_PATH_2 = "../data/broad_tcga/clinical/gdac.broadinstitute.org_STAD.Merge_Clinical.Level_1.2016012800.0.0.tar.gz"

df1 = pd.read_csv(CLINICAL_DATA_PATH_1, index_col=0, sep='\t')
# df2 = pd.read_csv(CLINICAL_DATA_PATH_2, sep='\t')  # for now seems not necessary

# %%
print(df1.shape)
df1.head()
# Out:
# (143, 443)
#                                                                             tcga-cg-4444  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    5c087d33-0bd3-407d-8350-fabba6aec597
# patient_id                                                                          4444
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               1431
#
#                                                                             tcga-cg-4460  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    3c3d4ef0-019a-423e-89b2-4ac5a7b567ab
# patient_id                                                                          4460
# vital_status                                                                        dead
# days_to_death                                                                        669
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-cg-4475  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    cad2adc1-0f41-4651-9c80-ae9961e2dc8d
# patient_id                                                                          4475
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                699
#
#                                                                             tcga-cg-4476  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    442d7415-d095-4962-8296-a14390bad40a
# patient_id                                                                          4476
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                  0
#
#                                                                             tcga-cg-5716  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    49587564-e30f-4f1c-b7b3-fc0989bb1a0a
# patient_id                                                                          5716
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                  0
#
#                                                                             tcga-cg-5727  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    b75eb694-8e9d-4dbb-b536-7d278c728cbb
# patient_id                                                                          5727
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               2405
#
#                                                                             tcga-eq-a4so  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    fe1ad544-3189-4495-86be-0c68f3234238
# patient_id                                                                          a4so
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                494
#
#                                                                             tcga-f1-6177  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    c3cba26e-38c2-4569-afd6-6b045e604808
# patient_id                                                                          6177
# vital_status                                                                        dead
# days_to_death                                                                        NaN
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-fp-a8cx  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    feb5ccf3-395f-415a-85d3-db637fcd514f
# patient_id                                                                          a8cx
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                  7
#
#                                                                             tcga-hf-7131  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    06fd3086-0801-4d74-bced-4916efc544d2
# patient_id                                                                          7131
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                NaN
#
#                                                     ...  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...  ...
# bcr_patient_uuid                                    ...
# patient_id                                          ...
# vital_status                                        ...
# days_to_death                                       ...
# days_to_last_followup                               ...
#
#                                                                             tcga-vq-aa6a  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    eb7e9aad-95d3-4efc-a706-e2c986d17055
# patient_id                                                                          aa6a
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               1184
#
#                                                                             tcga-vq-aa6b  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    40cb6f49-3d68-45dc-9bfa-b4d724de7dfe
# patient_id                                                                          aa6b
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               1002
#
#                                                                             tcga-vq-aa6d  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    5779f7a7-05d7-4972-bd4f-aacb32420510
# patient_id                                                                          aa6d
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                521
#
#                                                                             tcga-vq-aa6f  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    dccd3854-8865-4452-9f1c-97283509b553
# patient_id                                                                          aa6f
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               1646
#
#                                                                             tcga-vq-aa6g  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    a3f03a0a-f251-4588-97bc-3403597a35ad
# patient_id                                                                          aa6g
# vital_status                                                                        dead
# days_to_death                                                                        792
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-aa6i  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    3ccbe7c7-c779-4a98-b495-ff020d3e9e55
# patient_id                                                                          aa6i
# vital_status                                                                        dead
# days_to_death                                                                        491
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-aa6j  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    a267ddb4-b2d9-4292-b120-6e13e70d01f8
# patient_id                                                                          aa6j
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                838
#
#                                                                             tcga-vq-aa6k  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    83a0f9ef-4bf0-4efe-8713-f8b6ab4f5773
# patient_id                                                                          aa6k
# vital_status                                                                        dead
# days_to_death                                                                        378
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-za-a8f6  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    9130c730-b0bc-4d3a-9ee1-09bf43d9bd67
# patient_id                                                                          a8f6
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                525
#
#                                                                             tcga-zq-a9cr
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    f76122f7-343a-4345-9fb6-e46ad0b75cb0
# patient_id                                                                          a9cr
# vital_status                                                                        dead
# days_to_death                                                                         24
# days_to_last_followup                                                                NaN
#
# [5 rows x 443 columns]

# %%
print("Clinical features available: \n")
[print(i) for i in df1.index];
# Out:
# Clinical features available:
#
# bcr_patient_uuid
# patient_id
# vital_status
# days_to_death
# days_to_last_followup
# additional_studies
# age_at_initial_pathologic_diagnosis
# anatomic_neoplasm_subdivision
# anatomic_neoplasm_subdivision_other
# antireflux_treatment
# antireflux_treatment_type-2
# antireflux_treatment_type
# b_symptoms
# barretts_esophagus
# bcr
# bcr_aliquot_uuid
# bcr_canonical_reason-2
# bcr_canonical_reason-3
# bcr_canonical_reason
# bcr_followup_barcode
# bcr_followup_uuid
# bcr_patient_canonical_status
# city_of_procurement
# clinical_m
# clinical_n
# clinical_stage
# clinical_t
# clinical_trail_drug_classification
# country_of_procurement
# day_of_dcc_upload
# day_of_form_completion
# days_to_birth
# days_to_index
# days_to_initial_pathologic_diagnosis
# days_to_psa
# disease_code
# drugs
# ethnicity
# extranodal_involvement
# family_history_of_stomach_cancer
# file_uuid
# follow_ups
# followup_case_report_form_submission_reason
# followup_treatment_success
# gender
# gleason_score
# h_pylori_infection
# histological_type
# history_of_neoadjuvant_treatment
# hiv_status
# hpv_call_1
# hpv_call_2
# hpv_call_3
# hpv_status
# icd_10
# icd_o_3_histology
# icd_o_3_site
# igcccg_stage
# informed_consent_verified
# lost_follow_up
# lymph_node_examined_count
# masaoka_stage
# mononucleotide_and_dinucleotide_marker_panel_analysis_status
# mononucleotide_marker_panel_analysis_status
# month_of_dcc_upload
# month_of_form_completion
# neoplasm_histologic_grade
# number_of_lymphnodes_positive_by_he
# number_of_lymphnodes_positive_by_ihc
# number_of_relatives_with_stomach_cancer
# other_dx
# pathologic_m
# pathologic_n
# pathologic_stage
# pathologic_t
# patient_death_reason
# person_neoplasm_cancer_status
# primary_lymph_node_presentation_assessment
# primary_pattern
# primary_therapy_outcome_success
# project_code
# psa_value
# race
# radiation_therapy
# radiation_type_notes
# radiations
# reflux_history
# residual_tumor
# secondary_pattern
# serum_markers
# system_version
# targeted_molecular_therapy
# tertiary_pattern
# tissue_prospective_collection_indicator
# tissue_retrospective_collection_indicator
# tissue_source_site
# tumor_tissue_site
# withdrawn
# year_of_dcc_upload
# year_of_form_completion
# year_of_initial_pathologic_diagnosis
# nan
# Composite Element REF
# years_to_birth
# vital_status
# days_to_death
# days_to_last_followup
# tumor_tissue_site
# pathologic_stage
# pathology_T_stage
# pathology_N_stage
# pathology_M_stage
# gender
# date_of_initial_pathologic_diagnosis
# radiation_therapy
# histological_type
# residual_tumor
# number_of_lymph_nodes
# race
# ethnicity
# nan
# a4e47f76c4674bd88b700fc10999ebbd STAD.clin.merged.picked.txt
# 3e3ed325bf1e9d66cbdc1cb94b99daae stage3_params_clin_selection_STAD.tsv
# nan
# bcr_patient_barcode
# =floor(-as.numeric(days_to_birth)/365.2422)
# =ifelse( vital_status  %in% "dead" ,1, 0)
# days_to_death
# days_to_last_followup
# tumor_tissue_site
# pathologic_stage
# pathologic_t
# pathologic_n
# pathologic_m
# gender
# =ifelse(days_to_initial_pathologic_diagnosis != 0, days_to_initial_pathologic_diagnosis, year_of_initial_pathologic_diagnosis)
# radiation_therapy
# histological_type
# residual_tumor
# number_of_lymphnodes_positive_by_he
# race
# ethnicity
# nan

# %%
# # select cols of interest
# cols = [bcr_patient_uuid
# patient_id
# vital_status
# days_to_death
#        barretts_esophagus
#        clinical_m
# clinical_n
# clinical_stage
# clinical_t
#        drugs
#        ethnicity
#        gender
#        h_pylori_infection
# histological_type
# history_of_neoadjuvant_treatment
#        neoplasm_histologic_grade
# number_of_lymphnodes_positive_by_he
# number_of_lymphnodes_positive_by_ihc
# number_of_relatives_with_stomach_cancer
# other_dx
#        pathologic_m
# pathologic_n
# pathologic_stage
# pathologic_t
# patient_death_reason
#        tumor_tissue_site
# pathologic_stage
# pathology_T_stage
# pathology_N_stage
# pathology_M_stage
#        radiation_therapy
# histological_type
# residual_tumor
# number_of_lymph_nodes
# race
# ethnicity]

# %%
cols = ['bcr_patient_uuid', "patient_id", 'histological_type', 'patient_death_reason']
df1.loc[cols].iloc[:3,:]
# Out:
#                                                                              tcga-cg-4444  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                     5c087d33-0bd3-407d-8350-fabba6aec597
# patient_id                                                                           4444
# histological_type                                   stomach, adenocarcinoma, diffuse type
#
#                                                                                          tcga-cg-4460  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 3c3d4ef0-019a-423e-89b2-4ac5a7b567ab
# patient_id                                                                                       4460
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                             tcga-cg-4475  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    cad2adc1-0f41-4651-9c80-ae9961e2dc8d
# patient_id                                                                          4475
# histological_type                                                                    NaN
#
#                                                                              tcga-cg-4476  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                     442d7415-d095-4962-8296-a14390bad40a
# patient_id                                                                           4476
# histological_type                                   stomach, adenocarcinoma, diffuse type
#
#                                                                                          tcga-cg-5716  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 49587564-e30f-4f1c-b7b3-fc0989bb1a0a
# patient_id                                                                                       5716
# histological_type                                   stomach, adenocarcinoma, not otherwise specifi...
#
#                                                                                          tcga-cg-5727  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 b75eb694-8e9d-4dbb-b536-7d278c728cbb
# patient_id                                                                                       5727
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                             tcga-eq-a4so  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    fe1ad544-3189-4495-86be-0c68f3234238
# patient_id                                                                          a4so
# histological_type                                                                    NaN
#
#                                                                                          tcga-f1-6177  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 c3cba26e-38c2-4569-afd6-6b045e604808
# patient_id                                                                                       6177
# histological_type                                   stomach, adenocarcinoma, not otherwise specifi...
#
#                                                                                 tcga-fp-a8cx  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                        feb5ccf3-395f-415a-85d3-db637fcd514f
# patient_id                                                                              a8cx
# histological_type                                   stomach adenocarcinoma, signet ring type
#
#                                                                                          tcga-hf-7131  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 06fd3086-0801-4d74-bced-4916efc544d2
# patient_id                                                                                       7131
# histological_type                                   stomach, adenocarcinoma, not otherwise specifi...
#
#                                                     ...  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...  ...
# bcr_patient_uuid                                    ...
# patient_id                                          ...
# histological_type                                   ...
#
#                                                                                          tcga-vq-aa6a  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 eb7e9aad-95d3-4efc-a706-e2c986d17055
# patient_id                                                                                       aa6a
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                          tcga-vq-aa6b  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 40cb6f49-3d68-45dc-9bfa-b4d724de7dfe
# patient_id                                                                                       aa6b
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                         tcga-vq-aa6d  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                5779f7a7-05d7-4972-bd4f-aacb32420510
# patient_id                                                                                      aa6d
# histological_type                                   stomach, intestinal adenocarcinoma, tubular type
#
#                                                                                          tcga-vq-aa6f  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 dccd3854-8865-4452-9f1c-97283509b553
# patient_id                                                                                       aa6f
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                          tcga-vq-aa6g  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 a3f03a0a-f251-4588-97bc-3403597a35ad
# patient_id                                                                                       aa6g
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                          tcga-vq-aa6i  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 3ccbe7c7-c779-4a98-b495-ff020d3e9e55
# patient_id                                                                                       aa6i
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                          tcga-vq-aa6j  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 a267ddb4-b2d9-4292-b120-6e13e70d01f8
# patient_id                                                                                       aa6j
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                 tcga-vq-aa6k  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                        83a0f9ef-4bf0-4efe-8713-f8b6ab4f5773
# patient_id                                                                              aa6k
# histological_type                                   stomach adenocarcinoma, signet ring type
#
#                                                                                          tcga-za-a8f6  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                 9130c730-b0bc-4d3a-9ee1-09bf43d9bd67
# patient_id                                                                                       a8f6
# histological_type                                   stomach, intestinal adenocarcinoma, not otherw...
#
#                                                                                         tcga-zq-a9cr
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                                f76122f7-343a-4345-9fb6-e46ad0b75cb0
# patient_id                                                                                      a9cr
# histological_type                                   stomach, intestinal adenocarcinoma, tubular type
#
# [3 rows x 443 columns]

# %%
histotypes = df1.loc['histological_type'].iloc[0].to_list()
df_scr = df1.iloc[:, list(map(lambda x: bool(re.search(r'signet ring type', str(x))), histotypes))]

# %%
df_scr.shape
# Out:
# (143, 13)

# %%
df_scr.head()
# Out:
#                                                                             tcga-fp-a8cx  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    feb5ccf3-395f-415a-85d3-db637fcd514f
# patient_id                                                                          a8cx
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                  7
#
#                                                                             tcga-kb-a93g  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    e52396d1-acd6-44f4-99c5-1a367128008d
# patient_id                                                                          a93g
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                613
#
#                                                                             tcga-vq-a94u  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    a0402de7-08ae-4528-9e77-289295ad8ef8
# patient_id                                                                          a94u
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                                819
#
#                                                                             tcga-br-a453  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    1a1d4702-254b-4fff-9609-182442edb83e
# patient_id                                                                          a453
# vital_status                                                                        dead
# days_to_death                                                                        185
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-fp-a4bf  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    0ae2b51d-aade-4d24-8d0b-6990123d9074
# patient_id                                                                          a4bf
# vital_status                                                                        dead
# days_to_death                                                                        168
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-hj-7597  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    83d681f4-6c0e-45cc-a31d-0b1b31c8e073
# patient_id                                                                          7597
# vital_status                                                                        dead
# days_to_death                                                                        805
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-a8dz  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    a8a9b061-b33c-4c69-bd4c-7f430474cdfd
# patient_id                                                                          a8dz
# vital_status                                                                        dead
# days_to_death                                                                        396
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-a8pc  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    26f3ee89-7f74-4c4e-ad6f-fab29a5460f9
# patient_id                                                                          a8pc
# vital_status                                                                        dead
# days_to_death                                                                       1407
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-a8pm  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    bab53c56-82f1-4d63-98f5-4608ea7b5f4e
# patient_id                                                                          a8pm
# vital_status                                                                        dead
# days_to_death                                                                         57
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-a8po  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    4ec9dbb4-358d-4c59-8039-552c7006c2bf
# patient_id                                                                          a8po
# vital_status                                                                        dead
# days_to_death                                                                        282
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-a8pz  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    91c94a0d-f088-40e6-a4b1-d2a72ad35077
# patient_id                                                                          a8pz
# vital_status                                                                       alive
# days_to_death                                                                        NaN
# days_to_last_followup                                                               2233
#
#                                                                             tcga-vq-a94p  \
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    a205522f-2df0-4829-b86f-fa43c76c39cc
# patient_id                                                                          a94p
# vital_status                                                                        dead
# days_to_death                                                                         81
# days_to_last_followup                                                                NaN
#
#                                                                             tcga-vq-aa6k
# gdac.broadinstitute.org_STAD.Clinical_Pick_Tier...
# bcr_patient_uuid                                    83a0f9ef-4bf0-4efe-8713-f8b6ab4f5773
# patient_id                                                                          aa6k
# vital_status                                                                        dead
# days_to_death                                                                        378
# days_to_last_followup                                                                NaN

# %%
df_scr.columns
# Out:
# Index(['tcga-fp-a8cx', 'tcga-kb-a93g', 'tcga-vq-a94u', 'tcga-br-a453',
#        'tcga-fp-a4bf', 'tcga-hj-7597', 'tcga-vq-a8dz', 'tcga-vq-a8pc',
#        'tcga-vq-a8pm', 'tcga-vq-a8po', 'tcga-vq-a8pz', 'tcga-vq-a94p',
#        'tcga-vq-aa6k'],
#       dtype='object')

# %%
" ".join([s.upper() for s in df_scr.columns])
# Out:
# 'TCGA-FP-A8CX TCGA-KB-A93G TCGA-VQ-A94U TCGA-BR-A453 TCGA-FP-A4BF TCGA-HJ-7597 TCGA-VQ-A8DZ TCGA-VQ-A8PC TCGA-VQ-A8PM TCGA-VQ-A8PO TCGA-VQ-A8PZ TCGA-VQ-A94P TCGA-VQ-AA6K'

# %%
df_scr.index.rename('id', inplace=True)
df_scr.transpose()[['gender', 'race', 'pathologic_stage', 
                    "pathologic_m", "pathologic_n","pathologic_t",
                    'vital_status', "other_dx", "days_to_death",
                    'radiation_therapy']]

# To add: surgery? chemotherapy? radiation treatment? response to any of these? ...
# Can't evaluate response to treatment in SRC since not enough samples
# Can't evaluate severity of SRC correlations since not enough samples
# Maybe can identify omics specific features of SRC (t-tests, ...) ? Look into the methodology of Broad gdac and apply
# for the specific case of SRC ! (if significant p-values --> report.)
# Out:
# id            gender  gender gender                       race  \
# tcga-fp-a8cx    male    male    NaN                      white
# tcga-kb-a93g    male    male    NaN                      white
# tcga-vq-a94u    male    male    NaN                      white
# tcga-br-a453    male    male    NaN                      asian
# tcga-fp-a4bf    male    male    NaN                      white
# tcga-hj-7597  female  female    NaN                      white
# tcga-vq-a8dz    male    male    NaN  black or african american
# tcga-vq-a8pc    male    male    NaN                      white
# tcga-vq-a8pm    male    male    NaN                      white
# tcga-vq-a8po    male    male    NaN                      white
# tcga-vq-a8pz  female  female    NaN                      white
# tcga-vq-a94p    male    male    NaN                      white
# tcga-vq-aa6k    male    male    NaN                      white
#
# id                                 race race pathologic_stage  \
# tcga-fp-a8cx                      white  NaN       stage iiic
# tcga-kb-a93g                      white  NaN         stage ib
# tcga-vq-a94u                      white  NaN        stage iib
# tcga-br-a453                      asian  NaN         stage iv
# tcga-fp-a4bf                      white  NaN       stage iiia
# tcga-hj-7597                      white  NaN         stage ib
# tcga-vq-a8dz  black or african american  NaN         stage iv
# tcga-vq-a8pc                      white  NaN       stage iiia
# tcga-vq-a8pm                      white  NaN         stage iv
# tcga-vq-a8po                      white  NaN        stage iib
# tcga-vq-a8pz                      white  NaN         stage ii
# tcga-vq-a94p                      white  NaN              NaN
# tcga-vq-aa6k                      white  NaN       stage iiic
#
# id           pathologic_stage pathologic_stage pathologic_m  ... pathologic_t  \
# tcga-fp-a8cx       stage iiic              NaN           mx  ...          NaN
# tcga-kb-a93g         stage ib              NaN           m0  ...          NaN
# tcga-vq-a94u        stage iib              NaN           m0  ...          NaN
# tcga-br-a453         stage iv              NaN           m1  ...          NaN
# tcga-fp-a4bf       stage iiia              NaN           m0  ...          NaN
# tcga-hj-7597         stage ib              NaN           mx  ...          NaN
# tcga-vq-a8dz         stage iv              NaN           m1  ...          NaN
# tcga-vq-a8pc       stage iiia              NaN           m0  ...          NaN
# tcga-vq-a8pm         stage iv              NaN           m0  ...          NaN
# tcga-vq-a8po        stage iib              NaN           m0  ...          NaN
# tcga-vq-a8pz         stage ii              NaN           m0  ...          NaN
# tcga-vq-a94p              NaN              NaN           mx  ...          NaN
# tcga-vq-aa6k       stage iiic              NaN           m0  ...          NaN
#
# id           vital_status vital_status                          other_dx  \
# tcga-fp-a8cx        alive            0  yes, history of prior malignancy
# tcga-kb-a93g        alive            0  yes, history of prior malignancy
# tcga-vq-a94u        alive            0  yes, history of prior malignancy
# tcga-br-a453         dead            1                                no
# tcga-fp-a4bf         dead            1                                no
# tcga-hj-7597         dead            1                                no
# tcga-vq-a8dz         dead            1                                no
# tcga-vq-a8pc         dead            1                                no
# tcga-vq-a8pm         dead            1                                no
# tcga-vq-a8po         dead            1                                no
# tcga-vq-a8pz        alive            0                                no
# tcga-vq-a94p         dead            1                                no
# tcga-vq-aa6k         dead            1                                no
#
# id           days_to_death days_to_death days_to_death radiation_therapy  \
# tcga-fp-a8cx           NaN           NaN           NaN               NaN
# tcga-kb-a93g           NaN           NaN           NaN                no
# tcga-vq-a94u           NaN           NaN           NaN               yes
# tcga-br-a453           185           185           NaN                no
# tcga-fp-a4bf           168           168           NaN                no
# tcga-hj-7597           805           805           NaN                no
# tcga-vq-a8dz           396           396           NaN                no
# tcga-vq-a8pc          1407          1407           NaN                no
# tcga-vq-a8pm            57            57           NaN                no
# tcga-vq-a8po           282           282           NaN                no
# tcga-vq-a8pz           NaN           NaN           NaN               yes
# tcga-vq-a94p            81            81           NaN                no
# tcga-vq-aa6k           378           378           NaN               yes
#
# id           radiation_therapy radiation_therapy
# tcga-fp-a8cx               NaN               NaN
# tcga-kb-a93g                no               NaN
# tcga-vq-a94u               yes               NaN
# tcga-br-a453                no               NaN
# tcga-fp-a4bf                no               NaN
# tcga-hj-7597                no               NaN
# tcga-vq-a8dz                no               NaN
# tcga-vq-a8pc                no               NaN
# tcga-vq-a8pm                no               NaN
# tcga-vq-a8po                no               NaN
# tcga-vq-a8pz               yes               NaN
# tcga-vq-a94p                no               NaN
# tcga-vq-aa6k               yes               NaN
#
# [13 rows x 24 columns]
